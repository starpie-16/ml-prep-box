# %% [markdown]
# <a href="https://colab.research.google.com/github/starpie-16/ml-prep-box/blob/main/autoprep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
